# %%
import requests
 
payload = {
    "table_name": "UEFA_DEV_DWH.SOME_TABLE",
    "sample_rows": 50
}
 
response = requests.get("http://127.0.0.1:8000/run", json=payload)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'columns_output': 84, 'feature_importance_path': 'data/output/reports/fraud_feature_importance.csv', 'fraud_score_summary_path': 'data/output/reports/fraud_score_summary.csv', 'fraud_tier_summary_path': 'data/output/reports/fraud_tier_summary.csv', 'rows_processed': 100, 'run_id': '42887c74-ee69-4b81-9c05-d82db044db67', 'status': 'success', 'table_name': 'UEFA_DEV_DWH.ML_SANDBOX.DS_LOTTERY_AI_DATA_CLEANSING_UECLF24', 'timestamp': '2025-10-27T10:07:18.836902'}

# %%
response = requests.get("http://127.0.0.1:8000/healthcheck")
print(response.status_code)
# Out:
# 200
