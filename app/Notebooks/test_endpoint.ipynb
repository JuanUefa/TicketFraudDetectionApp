# %%
import requests

# %%
response = requests.get("http://127.0.0.1:8000/healthcheck")
print(response.status_code)
# Out:
# 200

# %%
payload = {
    "table_name": "UEFA_DEV_DWH.ML_SANDBOX.DS_LOTTERY_AI_DATA_CLEANSING_UECLF24",
    "sample_rows": 50
}
 
response = requests.post("http://127.0.0.1:8000/run", json=payload)
print(response.status_code)
print(response.json())

# %%
# Out:
# 200
